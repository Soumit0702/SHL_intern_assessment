# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/shl-hiring-assessment/Dataset/sample_submission.csv
# /kaggle/input/shl-hiring-assessment/Dataset/train.csv
# /kaggle/input/shl-hiring-assessment/Dataset/test.csv
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_885.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1142.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1006.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_817.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_765.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_508.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_257.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_330.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_72.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_328.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_858.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_464.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_505.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_853.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1001.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_855.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_995.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_472.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1028.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_550.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_841.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_256.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_641.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1131.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_234.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_284.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_188.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1220.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_67.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_818.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_967.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_709.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_872.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1165.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_415.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_714.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1231.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_430.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_27.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1207.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_922.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_976.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1180.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_327.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1212.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1092.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1270.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1163.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1041.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_940.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_563.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_661.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_220.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_57.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1136.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1179.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_41.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_590.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1294.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_161.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1069.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_261.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1246.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_89.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_952.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_846.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_909.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1088.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_989.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_865.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_278.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1300.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_298.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_178.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_674.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1104.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_966.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1134.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1079.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1329.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_542.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_954.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_171.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_530.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_822.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_14.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_689.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_309.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1046.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_502.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_568.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_80.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_13.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_668.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1170.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_47.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_218.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1316.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_904.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_268.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_130.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_273.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_962.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1226.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_452.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_585.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1286.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_692.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_357.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_335.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_681.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1186.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_766.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_686.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1099.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_339.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_534.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_531.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1326.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_397.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1218.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_453.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_670.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1090.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1102.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_24.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_978.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_746.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1158.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_682.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_324.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_358.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_377.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_744.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_249.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_956.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_854.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_981.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_245.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_903.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_749.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_929.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_529.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_828.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_236.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_200.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_935.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1200.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_353.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1055.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1255.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_501.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_947.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1217.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_804.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_168.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_701.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_117.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_780.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1059.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_390.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_599.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_153.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_988.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_241.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_481.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_652.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_483.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_787.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1291.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1258.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1039.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_902.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_373.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1138.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1025.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_647.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1225.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1011.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_108.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_34.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_938.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_376.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_769.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_554.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_407.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_99.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_449.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_548.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_664.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_33.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_248.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_774.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_827.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_748.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_301.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_128.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_637.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_267.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_915.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1166.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_450.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_612.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/test/audio_1187.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_698.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1176.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_77.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1215.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_66.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_894.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_54.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1232.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_694.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_237.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1032.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_688.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_752.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_596.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_638.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_886.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_711.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_741.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_936.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_538.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1271.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_859.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_845.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_821.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_164.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1266.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1005.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1036.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_994.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_760.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_315.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1284.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1152.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_843.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_25.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_950.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1199.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_753.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1322.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1224.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_7.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1100.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1157.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_406.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_321.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_20.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_59.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_802.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_518.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1310.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_12.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_591.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_348.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1082.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_537.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_444.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_959.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_404.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_254.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_338.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_990.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_233.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_539.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_276.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1323.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_157.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_778.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_354.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_29.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_676.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_37.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_454.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_811.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1183.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_946.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_600.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1277.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_901.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_199.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1336.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1297.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_308.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_251.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_232.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1054.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_631.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_495.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_265.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1098.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_662.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_558.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_900.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_470.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_673.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_964.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_633.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_418.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_274.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_280.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_486.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1337.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_231.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_567.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_374.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1194.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_944.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_856.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1084.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_230.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1306.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_120.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_295.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_297.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_899.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_516.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_56.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1103.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_346.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1007.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_446.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_189.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1236.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_277.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_957.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_491.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1012.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_190.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_759.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_642.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_347.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_824.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_851.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_457.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1253.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1171.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_773.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_76.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_905.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1015.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_205.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_361.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1035.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1159.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_497.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_928.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_102.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_399.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_296.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_860.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_942.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_881.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_499.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1116.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_393.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_275.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_779.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1278.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_370.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_410.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1197.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_565.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_807.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1241.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_4.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_356.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_162.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_118.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1202.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_974.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_366.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_743.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_210.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_19.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1228.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_998.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1018.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_614.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_396.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1239.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_583.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1114.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_771.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1049.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_829.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1058.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1182.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1094.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_719.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1205.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_930.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_801.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1091.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_217.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_84.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_575.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_475.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1045.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_258.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_23.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_593.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_592.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_423.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1237.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_916.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_159.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_522.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_545.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_387.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_266.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_372.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_784.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1133.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_93.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_331.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_849.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_934.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_215.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_826.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_659.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_364.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_654.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1083.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_174.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_816.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_987.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_5.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_551.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1120.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1128.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1066.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1119.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1221.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_628.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_622.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_763.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_355.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_553.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_85.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_574.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_182.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_756.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_800.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_38.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_469.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_965.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_148.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_127.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_677.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_434.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_691.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1075.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1030.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_239.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_252.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_871.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_326.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_288.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_98.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1105.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_286.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_263.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_209.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_656.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_302.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_984.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_52.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_16.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_844.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_460.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1111.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_594.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_679.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1076.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_764.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_332.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1151.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1335.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1173.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_78.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_388.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_700.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_224.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_939.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1282.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1002.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_375.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_383.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_996.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_921.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_515.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_30.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_745.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_216.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1192.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1219.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_949.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_459.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_362.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_908.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_482.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_158.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1042.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_219.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1309.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_533.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_154.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_958.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1249.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_805.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_630.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_730.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_611.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_92.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_69.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_385.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_221.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_131.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_336.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_880.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_707.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1238.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1330.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_742.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_292.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_754.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_716.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1276.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_985.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1161.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_840.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1029.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_68.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_671.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_432.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1078.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_155.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_378.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_264.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_360.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_349.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1240.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_212.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_183.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_474.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_419.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_316.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1332.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_242.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_667.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1254.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1072.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1132.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_825.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_586.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_226.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_426.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1019.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_39.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_890.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_197.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_213.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1168.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1290.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1339.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_136.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_893.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1314.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_687.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_312.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_147.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_783.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_144.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_710.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_706.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_573.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1214.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_139.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_503.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_134.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_18.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_116.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_789.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1087.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_523.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_420.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1156.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_135.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1223.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_325.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_556.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_669.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_755.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_973.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_678.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_655.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1265.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_250.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1299.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1174.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_512.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_150.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_392.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_73.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_43.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_712.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_437.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_613.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_493.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_704.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_431.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_3.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_832.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_428.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_658.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_58.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_471.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1117.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_713.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_768.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_640.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1023.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_566.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1135.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_36.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_201.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_74.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1320.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1127.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_993.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_480.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_560.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_877.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_852.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1096.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_514.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_696.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_1234.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_151.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_557.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_473.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_651.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_724.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_259.wav
# /kaggle/input/shl-hiring-assessment/Dataset/audios/train/audio_795.wav

# %%
# !pip install language_tool_python
# Out:
# Collecting language_tool_python
#   Downloading language_tool_python-2.9.3-py3-none-any.whl.metadata (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from language_tool_python) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from language_tool_python) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from language_tool_python) (7.0.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.11/dist-packages (from language_tool_python) (0.10.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->language_tool_python) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->language_tool_python) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->language_tool_python) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->language_tool_python) (2025.1.31)
# Downloading language_tool_python-2.9.3-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: language_tool_python
# Successfully installed language_tool_python-2.9.3

# %% [markdown]
# ## Imports

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import librosa
import pandas as pd
import numpy as np
from tqdm import tqdm 
from transformers import pipeline
import language_tool_python
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# Out:
# 2025-05-05 15:58:39.236368: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746460719.536957      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746460719.626170      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ## Update JAVA version

# %%
# !apt-get install -y openjdk-17-jdk
# !update-alternatives --set java /usr/lib/jvm/java-17-openjdk-amd64/bin/java

# !java -version

# !pip install --upgrade language-tool-python
# Out:
# The following additional packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libatk-wrapper-java libatk-wrapper-java-jni libxtst6
#   libxxf86dga1 openjdk-17-jdk-headless openjdk-17-jre openjdk-17-jre-headless x11-utils
# Suggested packages:
#   openjdk-17-demo openjdk-17-source visualvm libnss-mdns fonts-ipafont-gothic fonts-ipafont-mincho
#   fonts-wqy-microhei | fonts-wqy-zenhei fonts-indic mesa-utils
# The following NEW packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libatk-wrapper-java libatk-wrapper-java-jni libxtst6
#   libxxf86dga1 openjdk-17-jdk openjdk-17-jdk-headless openjdk-17-jre openjdk-17-jre-headless
#   x11-utils
# 0 upgraded, 11 newly installed, 0 to remove and 122 not upgraded.
# Need to get 125 MB of archives.
# After this operation, 286 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 openjdk-17-jre-headless amd64 17.0.14+7-1~22.04.1 [48.3 MB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 openjdk-17-jre amd64 17.0.14+7-1~22.04.1 [232 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 openjdk-17-jdk-headless amd64 17.0.14+7-1~22.04.1 [71.3 MB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 openjdk-17-jdk amd64 17.0.14+7-1~22.04.1 [1,521 kB]
# Fetched 125 MB in 4s (28.1 MB/s)
# Selecting previously unselected package fonts-dejavu-core.
# (Reading database ... 128691 files and directories currently installed.)
# Preparing to unpack .../00-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../01-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../02-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../03-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../04-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../05-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../06-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Selecting previously unselected package openjdk-17-jre-headless:amd64.
# Preparing to unpack .../07-openjdk-17-jre-headless_17.0.14+7-1~22.04.1_amd64.deb ...
# Unpacking openjdk-17-jre-headless:amd64 (17.0.14+7-1~22.04.1) ...
# Selecting previously unselected package openjdk-17-jre:amd64.
# Preparing to unpack .../08-openjdk-17-jre_17.0.14+7-1~22.04.1_amd64.deb ...
# Unpacking openjdk-17-jre:amd64 (17.0.14+7-1~22.04.1) ...
# Selecting previously unselected package openjdk-17-jdk-headless:amd64.
# Preparing to unpack .../09-openjdk-17-jdk-headless_17.0.14+7-1~22.04.1_amd64.deb ...
# Unpacking openjdk-17-jdk-headless:amd64 (17.0.14+7-1~22.04.1) ...
# Selecting previously unselected package openjdk-17-jdk:amd64.
# Preparing to unpack .../10-openjdk-17-jdk_17.0.14+7-1~22.04.1_amd64.deb ...
# Unpacking openjdk-17-jdk:amd64 (17.0.14+7-1~22.04.1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up openjdk-17-jre-headless:amd64 (17.0.14+7-1~22.04.1) ...
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/java to provide /usr/bin/java (java) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jpackage to provide /usr/bin/jpackage (jpackage) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/keytool to provide /usr/bin/keytool (keytool) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/rmiregistry to provide /usr/bin/rmiregistry (rmiregistry) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/lib/jexec to provide /usr/bin/jexec (jexec) in auto mode
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up openjdk-17-jre:amd64 (17.0.14+7-1~22.04.1) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up openjdk-17-jdk-headless:amd64 (17.0.14+7-1~22.04.1) ...
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jar to provide /usr/bin/jar (jar) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jarsigner to provide /usr/bin/jarsigner (jarsigner) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/javac to provide /usr/bin/javac (javac) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/javadoc to provide /usr/bin/javadoc (javadoc) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/javap to provide /usr/bin/javap (javap) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jcmd to provide /usr/bin/jcmd (jcmd) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jdb to provide /usr/bin/jdb (jdb) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jdeprscan to provide /usr/bin/jdeprscan (jdeprscan) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jdeps to provide /usr/bin/jdeps (jdeps) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jfr to provide /usr/bin/jfr (jfr) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jimage to provide /usr/bin/jimage (jimage) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jinfo to provide /usr/bin/jinfo (jinfo) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jlink to provide /usr/bin/jlink (jlink) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jmap to provide /usr/bin/jmap (jmap) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jmod to provide /usr/bin/jmod (jmod) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jps to provide /usr/bin/jps (jps) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jrunscript to provide /usr/bin/jrunscript (jrunscript) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jshell to provide /usr/bin/jshell (jshell) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jstack to provide /usr/bin/jstack (jstack) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jstat to provide /usr/bin/jstat (jstat) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jstatd to provide /usr/bin/jstatd (jstatd) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/serialver to provide /usr/bin/serialver (serialver) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jhsdb to provide /usr/bin/jhsdb (jhsdb) in auto mode
# Setting up openjdk-17-jdk:amd64 (17.0.14+7-1~22.04.1) ...
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jconsole to provide /usr/bin/jconsole (jconsole) in auto mode
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# openjdk version "17.0.14" 2025-01-21
# OpenJDK Runtime Environment (build 17.0.14+7-Ubuntu-122.04.1)
# OpenJDK 64-Bit Server VM (build 17.0.14+7-Ubuntu-122.04.1, mixed mode, sharing)
# Requirement already satisfied: language-tool-python in /usr/local/lib/python3.11/dist-packages (2.9.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from language-tool-python) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from language-tool-python) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from language-tool-python) (7.0.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.11/dist-packages (from language-tool-python) (0.10.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->language-tool-python) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->language-tool-python) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->language-tool-python) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->language-tool-python) (2025.1.31)

# %% [markdown]
# ## Device assignment

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Data Loading
train_df = pd.read_csv('/kaggle/input/shl-hiring-assessment/Dataset/train.csv')
test_df = pd.read_csv('/kaggle/input/shl-hiring-assessment/Dataset/test.csv')

# %% [markdown]
# ## Extract Audio Features Function

# %%
# Feature Extraction Functions
def extract_audio_features(file_path):
    y, sr = librosa.load(file_path, sr=16000)
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40)
    chroma = librosa.feature.chroma_stft(y=y, sr=sr)
    contrast = librosa.feature.spectral_contrast(y=y, sr=sr)
    return np.concatenate([np.mean(mfcc, axis=1), 
                          np.mean(chroma, axis=1), 
                          np.mean(contrast, axis=1)])

asr_pipe = pipeline("automatic-speech-recognition", 
                   model="openai/whisper-medium",
                   device=0 if torch.cuda.is_available() else -1,
                   return_timestamps=True)

tool = language_tool_python.LanguageTool('en-US')

def process_text_features(text):
    matches = tool.check(text)
    error_count = len(matches)
    error_types = len({m.ruleId for m in matches})
    word_count = len(text.split())
    return np.array([error_count, error_types, word_count])
# Out:
# config.json:   0%|          | 0.00/1.99k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.06G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/3.75k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/283k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/836k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.19k [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/185k [00:00<?, ?B/s]
# Device set to use cuda:0
# Downloading LanguageTool latest: 100%|██████████| 252M/252M [00:12<00:00, 20.2MB/s]

# %% [markdown]
# ## Preprocess Data Function

# %%
# Data Preprocessing
def preprocess_data(df, is_train=True, num_samples=None):
    features = []
    labels = [] if is_train else None
    
    for idx, row in tqdm(df.iterrows()):
        if is_train:
            file_path = '/kaggle/input/shl-hiring-assessment/Dataset/audios/train/' + row["filename"]
        else:
            file_path = '/kaggle/input/shl-hiring-assessment/Dataset/audios/test/' + row["filename"]  
        
        audio_feat = extract_audio_features(file_path)
        text = asr_pipe(file_path)["text"]
        text_feat = process_text_features(text)
        combined_feat = np.concatenate([audio_feat, text_feat])
        features.append(combined_feat)
        
        if is_train:
            labels.append(row['label'])
    
    return (np.array(features), np.array(labels)) if is_train else np.array(features)

# %% [markdown]
# ## Spliting Training and Validation

# %%
X_train, y_train = preprocess_data(train_df, num_samples=300)

# Split for validation
X_train_full, X_val, y_train_full, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=42
)

# Feature scaling
audio_scaler = StandardScaler().fit(X_train_full[:, :59])
text_scaler = StandardScaler().fit(X_train_full[:, 59:])

def scale_features(features):
    audio = audio_scaler.transform(features[:, :59])
    text = text_scaler.transform(features[:, 59:])
    return np.concatenate([audio, text], axis=1)

X_train_scaled = scale_features(X_train_full)
X_val_scaled = scale_features(X_val)
# Out:
# 0it [00:00, ?it/s]Due to a bug fix in https://github.com/huggingface/transformers/pull/28687 transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English.This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 1it [00:50, 50.48s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 2it [00:53, 22.54s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 3it [01:21, 25.26s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 4it [01:25, 16.60s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 5it [01:30, 12.41s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 8it [01:42,  6.32s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 9it [01:48,  6.20s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 10it [02:00,  8.07s/it]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 13it [02:15,  5.86s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 15it [02:24,  5.33s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 18it [02:38,  4.87s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 20it [02:48,  5.09s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 21it [02:52,  4.64s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 22it [03:20, 11.75s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 23it [03:26, 10.05s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 25it [03:37,  7.55s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 26it [03:42,  6.90s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 29it [03:55,  5.21s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 30it [04:01,  5.50s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 31it [04:06,  5.35s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 32it [04:11,  5.09s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 33it [04:15,  4.69s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 34it [04:20,  5.01s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 38it [04:40,  4.90s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 40it [04:48,  4.43s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 42it [04:56,  4.38s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 43it [05:00,  4.21s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 46it [05:15,  4.88s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 50it [05:30,  3.87s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 53it [05:43,  4.17s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 55it [05:54,  4.99s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 56it [05:58,  4.52s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 57it [06:01,  4.31s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 58it [06:06,  4.28s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 59it [06:11,  4.47s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 60it [06:16,  4.67s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 61it [06:20,  4.50s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 64it [06:34,  4.80s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 65it [06:39,  4.70s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 66it [07:07, 11.74s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 67it [07:11,  9.45s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 68it [07:16,  8.10s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 69it [07:20,  6.75s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 72it [07:35,  5.72s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 73it [07:54,  9.68s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 74it [08:00,  8.55s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 76it [08:34, 11.69s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 77it [08:39,  9.81s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 79it [08:48,  7.17s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 80it [08:54,  6.60s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 83it [09:08,  5.50s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 84it [09:36, 12.21s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 85it [09:41, 10.21s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 87it [09:51,  7.43s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 88it [09:57,  7.15s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 89it [10:01,  6.22s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 90it [10:06,  5.64s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 94it [10:24,  4.87s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 98it [10:42,  4.52s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 100it [10:49,  3.73s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 103it [11:04,  4.57s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 105it [11:14,  5.00s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 107it [11:25,  5.18s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 108it [11:53, 12.03s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 109it [11:58,  9.84s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 115it [12:26,  5.36s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 116it [12:31,  5.42s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 117it [12:50,  9.56s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 118it [12:55,  7.99s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 119it [13:00,  7.24s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 121it [13:08,  5.70s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 123it [13:18,  5.08s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 125it [14:01, 12.16s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 126it [14:06, 10.07s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 127it [14:34, 15.19s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 128it [14:55, 16.95s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 131it [15:34, 12.66s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 134it [15:49,  7.73s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 135it [15:54,  7.04s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 142it [16:28,  5.11s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 146it [16:52,  6.19s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 147it [17:20, 12.78s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 148it [17:25, 10.50s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 150it [18:19, 18.14s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 152it [18:43, 14.44s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 153it [18:58, 14.54s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 156it [19:12,  8.06s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 159it [19:27,  6.07s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 160it [19:33,  5.86s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 161it [19:38,  5.68s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 162it [19:51,  7.93s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 163it [19:57,  7.39s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 165it [20:13,  7.91s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 167it [20:25,  6.90s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 168it [20:29,  6.17s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 173it [20:52,  4.73s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 174it [20:57,  4.91s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 176it [21:08,  5.24s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 178it [21:24,  6.28s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 180it [21:33,  5.43s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 181it [21:38,  5.35s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 183it [21:49,  5.41s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 184it [21:54,  5.27s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 185it [22:12,  9.13s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 188it [22:27,  6.46s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 189it [22:33,  6.21s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 190it [23:01, 12.66s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 192it [23:11,  8.66s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 195it [23:20,  4.84s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 196it [23:25,  4.96s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 197it [23:33,  5.67s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 198it [23:36,  5.02s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 200it [23:46,  4.89s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 203it [23:59,  4.51s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 204it [24:03,  4.37s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 205it [24:08,  4.43s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 206it [24:14,  4.84s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 208it [24:44, 10.94s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 210it [25:00,  9.90s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 211it [25:06,  8.57s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 212it [25:15,  8.95s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 213it [25:20,  7.76s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 214it [25:41, 11.64s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 216it [25:52,  8.60s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 217it [25:58,  7.70s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 219it [26:07,  6.13s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 220it [26:12,  5.61s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 221it [26:39, 12.11s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 222it [26:44, 10.04s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 223it [26:49,  8.66s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 224it [26:56,  7.94s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 225it [27:02,  7.54s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 226it [27:07,  6.69s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 227it [27:19,  8.17s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 228it [27:23,  7.03s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 229it [27:28,  6.48s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 230it [27:33,  6.12s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 231it [27:38,  5.62s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 233it [27:48,  5.34s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 234it [27:53,  5.27s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 236it [28:11,  6.80s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 239it [28:35,  7.05s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 242it [29:03,  7.78s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 245it [29:55, 12.32s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 246it [30:05, 11.70s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 249it [30:21,  7.30s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 251it [30:31,  6.10s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 254it [31:04,  8.15s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 257it [31:21,  6.33s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 258it [31:26,  5.99s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 259it [31:31,  5.60s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 261it [31:42,  5.42s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 263it [31:58,  6.56s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 266it [32:12,  5.14s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 267it [32:17,  5.15s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 269it [32:26,  4.83s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 270it [32:38,  6.85s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 273it [32:59,  6.66s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 274it [33:04,  6.08s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 276it [33:14,  5.71s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 280it [33:44,  7.89s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 285it [34:34,  8.31s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 288it [34:57,  7.86s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 289it [35:03,  7.09s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 290it [35:08,  6.61s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 294it [35:31,  6.03s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 295it [35:37,  5.97s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 296it [35:44,  6.15s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 297it [35:48,  5.64s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 298it [35:55,  6.08s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 299it [36:01,  6.04s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 302it [36:45, 10.90s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 303it [36:51,  9.35s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 306it [37:08,  6.88s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 309it [37:35,  7.61s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 311it [37:57,  9.93s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 312it [38:03,  8.51s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 315it [38:44, 11.60s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 317it [38:56,  8.88s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 319it [39:13,  8.95s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 321it [39:40, 11.41s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 322it [39:44,  9.36s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 323it [39:51,  8.71s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 326it [40:14,  8.22s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 327it [40:28, 10.10s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 328it [40:39, 10.34s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 329it [41:08, 15.83s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 330it [41:14, 12.88s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 332it [41:43, 12.77s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 334it [42:06, 12.05s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 335it [42:15, 11.22s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 336it [42:20,  9.21s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 338it [42:32,  7.51s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 339it [42:39,  7.62s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 342it [43:02,  7.92s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 343it [43:19, 10.67s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 346it [43:58, 12.76s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 347it [44:04, 10.54s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 348it [44:15, 10.69s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 350it [44:40, 12.27s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 351it [44:45, 10.27s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 352it [44:49,  8.39s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 354it [45:00,  6.73s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 355it [45:06,  6.57s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 356it [45:12,  6.37s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 363it [46:37,  9.39s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 369it [47:19,  6.31s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 370it [47:25,  6.17s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 372it [47:38,  6.39s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 373it [47:43,  6.16s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 375it [47:58,  6.59s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 376it [48:04,  6.31s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 378it [48:22,  7.47s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 382it [48:58, 10.10s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 383it [49:09, 10.22s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 385it [49:21,  8.17s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 386it [49:27,  7.53s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 387it [49:32,  6.83s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 388it [49:36,  5.90s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 391it [50:02,  8.32s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 392it [50:08,  7.53s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 394it [50:19,  6.41s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 396it [50:57, 11.56s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 397it [51:06, 10.89s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 398it [51:12,  9.42s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 400it [51:22,  6.94s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 403it [51:41,  6.46s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 405it [51:55,  6.59s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 406it [52:04,  7.56s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 410it [52:42,  9.42s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 416it [53:30,  6.65s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 418it [53:41,  6.03s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 426it [54:59,  7.76s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 427it [55:06,  7.38s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 430it [55:48, 11.66s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 431it [55:53,  9.77s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 433it [56:03,  7.38s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 434it [56:08,  6.77s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 435it [56:15,  6.71s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 438it [56:30,  5.56s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 442it [57:22, 10.29s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 444it [57:32,  7.78s/it]

# %% [markdown]
# ## Dataset and DataLoader

# %%
# Dataset and DataLoader
class GrammarDataset(Dataset):
    def __init__(self, features, labels):
        self.features = features
        self.labels = labels
        
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        return (
            torch.tensor(self.features[idx], dtype=torch.float32),
            torch.tensor(self.labels[idx], dtype=torch.float32)
        )


train_dataset = GrammarDataset(X_train_scaled, y_train_full)
val_dataset = GrammarDataset(X_val_scaled, y_val)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32)

# %% [markdown]
# ## Model

# %%
 # Model Architecture
class GrammarModel(nn.Module):
    def __init__(self, input_size):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )
    def forward(self, x):
        return self.net(x).squeeze()

model = GrammarModel(X_train_scaled.shape[1]).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.MSELoss()
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.2, patience=5)

# %% [markdown]
# ## Training

# %%
# Training with Early Stopping
best_loss = float('inf')
patience = 10
no_improve = 0
train_losses = []
val_losses = []

for epoch in range(100):
    # Training
    model.train()
    epoch_loss = 0
    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item() * inputs.size(0)
    train_loss = epoch_loss / len(train_loader.dataset)
    train_losses.append(train_loss)
    
    # Validation
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for inputs, targets in val_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            val_loss += criterion(outputs, targets).item() * inputs.size(0)
    val_loss /= len(val_loader.dataset)
    val_losses.append(val_loss)
    
    # Update scheduler
    scheduler.step(val_loss)
    
    # Early stopping
    if val_loss < best_loss:
        best_loss = val_loss
        no_improve = 0
        torch.save(model.state_dict(), 'best_model.pth')
    else:
        no_improve += 1
        
    print(f'Epoch {epoch+1:03d} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}')
    
    if no_improve >= patience:
        print(f'Early stopping at epoch {epoch+1}')
        break
# Out:
# Epoch 001 | Train Loss: 13.6597 | Val Loss: 9.1732
# Epoch 002 | Train Loss: 6.5797 | Val Loss: 2.9036
# Epoch 003 | Train Loss: 1.8787 | Val Loss: 2.3470
# Epoch 004 | Train Loss: 1.8681 | Val Loss: 1.6370
# Epoch 005 | Train Loss: 1.2994 | Val Loss: 1.6143
# Epoch 006 | Train Loss: 1.2225 | Val Loss: 1.5200
# Epoch 007 | Train Loss: 1.2645 | Val Loss: 1.5098
# Epoch 008 | Train Loss: 1.0881 | Val Loss: 1.4935
# Epoch 009 | Train Loss: 1.0329 | Val Loss: 1.4482
# Epoch 010 | Train Loss: 0.9931 | Val Loss: 1.4608
# Epoch 011 | Train Loss: 0.9502 | Val Loss: 1.4385
# Epoch 012 | Train Loss: 0.8983 | Val Loss: 1.4313
# Epoch 013 | Train Loss: 0.9282 | Val Loss: 1.4181
# Epoch 014 | Train Loss: 0.7857 | Val Loss: 1.3735
# Epoch 015 | Train Loss: 0.8433 | Val Loss: 1.3432
# Epoch 016 | Train Loss: 0.7998 | Val Loss: 1.3564
# Epoch 017 | Train Loss: 0.7007 | Val Loss: 1.4008
# Epoch 018 | Train Loss: 0.7684 | Val Loss: 1.3794
# Epoch 019 | Train Loss: 0.7514 | Val Loss: 1.3377
# Epoch 020 | Train Loss: 0.7113 | Val Loss: 1.3986
# Epoch 021 | Train Loss: 0.6949 | Val Loss: 1.2907
# Epoch 022 | Train Loss: 0.7048 | Val Loss: 1.3501
# Epoch 023 | Train Loss: 0.6649 | Val Loss: 1.3415
# Epoch 024 | Train Loss: 0.6914 | Val Loss: 1.3632
# Epoch 025 | Train Loss: 0.6539 | Val Loss: 1.3233
# Epoch 026 | Train Loss: 0.5716 | Val Loss: 1.2709
# Epoch 027 | Train Loss: 0.6039 | Val Loss: 1.2878
# Epoch 028 | Train Loss: 0.5952 | Val Loss: 1.2749
# Epoch 029 | Train Loss: 0.5376 | Val Loss: 1.2959
# Epoch 030 | Train Loss: 0.6208 | Val Loss: 1.2401
# Epoch 031 | Train Loss: 0.5651 | Val Loss: 1.3254
# Epoch 032 | Train Loss: 0.5378 | Val Loss: 1.2542
# Epoch 033 | Train Loss: 0.5496 | Val Loss: 1.3204
# Epoch 034 | Train Loss: 0.5428 | Val Loss: 1.2402
# Epoch 035 | Train Loss: 0.4816 | Val Loss: 1.2607
# Epoch 036 | Train Loss: 0.5609 | Val Loss: 1.2294
# Epoch 037 | Train Loss: 0.4804 | Val Loss: 1.3325
# Epoch 038 | Train Loss: 0.4887 | Val Loss: 1.2499
# Epoch 039 | Train Loss: 0.5217 | Val Loss: 1.2268
# Epoch 040 | Train Loss: 0.4780 | Val Loss: 1.2716
# Epoch 041 | Train Loss: 0.4486 | Val Loss: 1.2183
# Epoch 042 | Train Loss: 0.4543 | Val Loss: 1.2702
# Epoch 043 | Train Loss: 0.4269 | Val Loss: 1.2605
# Epoch 044 | Train Loss: 0.4243 | Val Loss: 1.2943
# Epoch 045 | Train Loss: 0.4579 | Val Loss: 1.3518
# Epoch 046 | Train Loss: 0.4713 | Val Loss: 1.2517
# Epoch 047 | Train Loss: 0.4331 | Val Loss: 1.2577
# Epoch 048 | Train Loss: 0.4429 | Val Loss: 1.2376
# Epoch 049 | Train Loss: 0.4356 | Val Loss: 1.2344
# Epoch 050 | Train Loss: 0.4266 | Val Loss: 1.2466
# Epoch 051 | Train Loss: 0.4263 | Val Loss: 1.2571
# Early stopping at epoch 51

# %% [markdown]
# ## Evaluation Metrics along with graphs loss curves and prediction distribution

# %%
# Load best model and evaluate
model.load_state_dict(torch.load('best_model.pth'))
model.eval()
with torch.no_grad():
    y_pred = model(torch.tensor(scale_features(X_train), dtype=torch.float32).to(device)).cpu().numpy()

y_pred_rounded = np.clip(np.round(y_pred), 1, 5).astype(int)

# Compute metrics
rmse = np.sqrt(mean_squared_error(y_train, y_pred_rounded))
mae = mean_absolute_error(y_train, y_pred_rounded)
r2 = r2_score(y_train, y_pred_rounded)
pearson, _ = pearsonr(y_train, y_pred_rounded)

print(f'Training Metrics:')
print(f'RMSE: {rmse:.4f}')
print(f'MAE: {mae:.4f}')
print(f'R²: {r2:.4f}')
print(f'Pearson: {pearson:.4f}')

# Visualization
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.legend()
plt.title('Loss Curves')

plt.subplot(1, 2, 2)
plt.scatter(y_train, y_pred_rounded, alpha=0.5)
plt.plot([1, 5], [1, 5], 'r--')
plt.xlabel('True Scores')
plt.ylabel('Predicted Scores')
plt.title('Prediction Distribution')
plt.tight_layout()
plt.show()
# Out:
# Training Metrics:
# RMSE: 0.6955
# MAE: 0.4696
# R²: 0.5593
# Pearson: 0.7514

# %% [markdown]
# ## Test Prediction

# %%
# Test Prediction
# Preprocess test data
X_test = preprocess_data(test_df, is_train=False)
X_test_scaled = scale_features(X_test)

# Predict
model.eval()
with torch.no_grad():
    test_pred = model(torch.tensor(X_test_scaled, dtype=torch.float32).to(device)).cpu().numpy()

test_pred_rounded = np.clip(np.round(test_pred), 1, 5).astype(int)

# Generate submission
submission_df = pd.DataFrame({
    'filename': test_df['filename'].values,
    'label': test_pred_rounded.flatten()
})

submission_df.to_csv("final_submission.csv", index=False)
# Out:
# 0it [00:00, ?it/s]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 3it [00:14,  4.91s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 4it [00:19,  5.17s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 8it [00:39,  5.07s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 13it [01:06,  5.19s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 15it [01:20,  6.21s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 16it [01:26,  6.11s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 17it [01:30,  5.77s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 19it [01:40,  5.22s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 20it [01:44,  4.93s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 23it [02:00,  4.92s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 24it [02:04,  4.66s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 26it [02:13,  4.74s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 31it [03:07,  7.18s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 32it [03:12,  6.63s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 35it [03:50,  8.88s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 36it [03:54,  7.46s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 37it [03:58,  6.42s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 38it [04:05,  6.43s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 42it [04:28,  6.35s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 44it [04:38,  5.69s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 46it [05:03,  9.59s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 47it [05:24, 13.14s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 50it [05:41,  8.04s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 51it [05:46,  7.38s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 55it [06:09,  5.95s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 57it [06:20,  5.65s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 59it [06:37,  6.59s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 60it [06:42,  6.34s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 61it [07:04, 11.05s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 63it [07:13,  7.69s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 64it [07:19,  7.20s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 67it [07:54,  9.09s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 68it [08:00,  8.14s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 69it [08:07,  7.60s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 71it [08:16,  6.01s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 72it [08:45, 12.88s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 73it [08:50, 10.51s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 76it [09:05,  6.79s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 77it [09:10,  6.27s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 78it [09:15,  5.83s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 79it [09:19,  5.39s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 80it [09:29,  6.79s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 83it [10:01,  7.94s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 84it [10:06,  7.04s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 86it [10:16,  6.09s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 89it [10:46,  8.61s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 90it [10:50,  7.38s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 91it [10:59,  7.63s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 92it [11:04,  7.08s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 93it [11:10,  6.54s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 94it [11:16,  6.36s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 95it [11:21,  6.08s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 97it [11:28,  4.66s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 98it [11:34,  5.06s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 99it [11:39,  5.15s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 100it [11:50,  6.92s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 102it [12:25, 11.19s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 106it [12:45,  6.50s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 107it [13:14, 13.25s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 108it [13:19, 10.64s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 111it [13:33,  6.92s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 112it [13:41,  7.22s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 113it [13:47,  6.73s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 114it [14:06, 10.42s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 115it [14:26, 13.46s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 116it [14:33, 11.58s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 117it [14:41, 10.38s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 119it [14:50,  7.47s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 124it [15:18,  6.26s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 125it [15:40, 10.79s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 128it [16:19, 10.63s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 129it [16:56, 18.40s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 130it [17:01, 14.61s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 131it [17:07, 11.84s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 132it [17:12,  9.90s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 133it [17:18,  8.63s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 134it [17:30,  9.86s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 137it [17:47,  7.08s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 139it [17:56,  5.61s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 140it [18:02,  5.84s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 144it [18:20,  4.80s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 147it [18:35,  4.89s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 149it [18:46,  5.15s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 150it [18:51,  5.08s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 153it [19:08,  5.53s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 155it [19:15,  4.25s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 157it [19:26,  5.02s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 159it [19:35,  4.65s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 160it [19:41,  5.01s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 161it [20:10, 12.22s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 163it [20:21,  8.81s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 166it [20:48,  8.74s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 168it [21:13, 10.20s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 169it [21:19,  8.95s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 170it [21:25,  8.05s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 171it [21:32,  7.51s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 176it [22:32,  9.79s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 180it [22:59,  7.83s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 181it [23:06,  7.51s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 182it [23:11,  6.80s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 185it [23:32,  6.76s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 190it [24:13,  8.38s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 195it [25:07, 11.98s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 196it [25:33, 16.38s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 197it [25:39, 13.12s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 199it [25:50,  9.28s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 200it [25:56,  8.35s/it]Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# 204it [26:17,  7.73s/it]
